# %% [markdown]
# # Set up

# %%
GITHUB_USER = 'tadtd'
REPO_NAME   = 'csc14005-introduction-to-machine-learning'
BRANCH      = 'lab-3'

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# %%
# !git clone --single-branch --branch {BRANCH} https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git

# %%
# %cd {REPO_NAME}
# %cd lab-3
# %cd probabilistic-circuit
# !ls

# %%
# !apt-get install poppler-utils
# !pip install --upgrade pip
# !pip install uv
# !uv python install 3.13
# !uv python pin 3.13
# !rm -rf pyproject.toml
# !rm -rf uv.lock
# !rm -rf .python-version

# %%
# %%writefile pyproject.toml
# [project]
# name = "probabilistic-circuit"
# version = "0.1.0"
# description = "probabilistic-circuit demo dependencies"
# readme = "README.md"
# requires-python = ">=3.13"
# dependencies = [
#     "libcirkit>=0.2.1",
#     "torch>=2.12.0",
#     "torchvision>=0.27.0",
# ]

# %%
# !uv sync

# %% [markdown]
# ## Demo

# %%
# !nvidia-smi

# %%
# !uv run experiments/run_toy.py --width 8 --epochs 300

# %%
# !uv run experiments/run_mnist.py --width 8 --epochs 1 --max-train 1000 --max-val 200 --max-test 200 --batch-size 128
